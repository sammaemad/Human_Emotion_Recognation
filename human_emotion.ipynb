# %%
# %pip install deepface
# Out:
# Requirement already satisfied: deepface in d:\anaconda\lib\site-packages (0.0.93)
# Requirement already satisfied: requests>=2.27.1 in c:\users\sama emad\appdata\roaming\python\python312\site-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in d:\anaconda\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in d:\anaconda\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in d:\anaconda\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in d:\anaconda\lib\site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in d:\anaconda\lib\site-packages (from deepface) (10.3.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in d:\anaconda\lib\site-packages (from deepface) (4.11.0.86)
# Requirement already satisfied: tensorflow>=1.9.0 in d:\anaconda\lib\site-packages (from deepface) (2.19.0)
# Requirement already satisfied: keras>=2.2.0 in d:\anaconda\lib\site-packages (from deepface) (3.9.2)
# Requirement already satisfied: Flask>=1.1.2 in d:\anaconda\lib\site-packages (from deepface) (3.0.3)
# Requirement already satisfied: flask-cors>=4.0.1 in d:\anaconda\lib\site-packages (from deepface) (5.0.1)
# Requirement already satisfied: mtcnn>=0.1.0 in d:\anaconda\lib\site-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in d:\anaconda\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in d:\anaconda\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in d:\anaconda\lib\site-packages (from deepface) (23.0.0)
# Requirement already satisfied: termcolor in d:\anaconda\lib\site-packages (from fire>=0.4.0->deepface) (3.0.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in d:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in d:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in d:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in d:\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (1.6.2)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.2)
# Requirement already satisfied: absl-py in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (2.2.2)
# Requirement already satisfied: rich in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.15.0)
# Requirement already satisfied: ml-dtypes in d:\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.5.1)
# Requirement already satisfied: joblib>=1.4.2 in d:\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in d:\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sama emad\appdata\roaming\python\python312\site-packages (from requests>=2.27.1->deepface) (2024.8.30)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.19.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in d:\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile human_emotions_rec.py
import streamlit as st
import cv2
import numpy as np
from PIL import Image
import tempfile
from deepface import DeepFace

st.title('Human Emotions Recognation App')
st.write('Upload an Image or video')

options = st.selectbox('Choose an option...',('Image', 'Video'))

def Analyze_Emotion(img_vid):
    try:
        analysis = DeepFace.analyze(img_vid,actions = ['emotion'], enforce_detection = False)
        return analysis[0]['emotion']

    except ValueError as e:
        st.write(f'Error: {e}')
        return None
    
if options == 'Image':
    upload = st.file_uploader('Upload an image, plz: ',type = ['jpg','png','jpeg'])
    if upload is not None:
        img = Image.open(upload)
        img_array = np.array(img)
        st.image(img_array, channels = 'RGB')

        emotion_scores = Analyze_Emotion(img_array)

        if emotion_scores:
            # emotion_scores = {'Happy': 0.7, 'sad': 0.3, 'angry': 0.2}
            detected_emotion = max(emotion_scores, key = emotion_scores.get)
            st.write(f'detected emotion: {detected_emotion}')
        else:
            st.write('No Face Detected in your img')
            
if options == 'Video':
    upload = st.file_uploader('Upload a video, plz: ',type = ['mp4','mov','avi'])
    if upload is not None:
        with tempfile.NamedTemporaryFile(delete = False) as temp_video:
            temp_video.write(upload.read())
            video_path = temp_video.name
        video = cv2.VideoCapture(video_path)

        frame_count = 0 
        farme_rate =50 # control how many frames 


        
        while video.isOpened():
            ret , farme = video.read()
            if not ret:
                break
            frame_count +=1

            if frame_count % farme_rate == 0:
                fram_rgb = cv2.cvtColor(farme,cv2.COLOR_BGR2RGB)
                emotion_scores = Analyze_Emotion(fram_rgb)
                if emotion_scores:
                    # emotion_scores = {'Happy': 0.7, 'sad': 0.3, 'angry': 0.2}
                    detected_emotion = max(emotion_scores, key = emotion_scores.get)
                    cv2.putText(farme, detected_emotion, (50,50), cv2.FONT_HERSHEY_SIMPLEX,3,(0,0,255),2)
                else:
                    detected_emotion = 'No Face Detected'
                    cv2.putText(farme, detected_emotion, (50,50), cv2.FONT_HERSHEY_SIMPLEX,3,(0,0,255),2)
                st.image(farme, channels = 'BGR')
        video.release()
# Out:
# Overwriting human_emotions_rec.py
